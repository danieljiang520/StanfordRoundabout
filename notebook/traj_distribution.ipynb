# %% [markdown]
# # Trajectory Distribution Fuzzing in Highway Roundabout
#
# This notebook demonstrates trajectory distribution fuzzing for the HighwayEnv roundabout environment.
#
# **Key Components** (now in `src/` modules):
# - `ScenarioParams`: Dataclass for configurable observation, action, and environment disturbances
# - `SimulatedEnv`: Custom roundabout environment with fuzzable parameters
# - `ScenarioFuzzer`: Class for rollouts and finding critical failure scenarios
#
# **Usage**: Create a `ScenarioFuzzer` with env and model, then call `fuzzer.rollout()` or `fuzzer.optimize()`

# %%
# Uncomment to install dependencies
# !pip install gymnasium stable_baselines3 opencv-python highway_env torch

# %%
# Use dummy video driver to prevent window from appearing
import os
# os.environ["SDL_VIDEODRIVER"] = "dummy" # uncomment later

import gymnasium as gym
from gymnasium.wrappers import RecordVideo
from stable_baselines3 import DQN

import numpy as np

# Import from src modules (auto-registers SimulatedEnv-v0)
from src import (
    ScenarioParams,
    GaussianMixtureParam,
    NormalParam,
    ProbabilityParam,
    BetaParam,
    NOMINAL,
    SQRT_2,
    SimulatedEnv,
    ScenarioFuzzer,
    FuzzerConfig,
    PARAM_NAMES,
    compute_robustness,
    weights_from_vector,
)
# Out:
# objc[17817]: Class SDLApplication is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728890) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d2c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLAppDelegate is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x1427288e0) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d318). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLTranslatorResponder is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728958) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d390). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLMessageBoxPresenter is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728980) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d3b8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_cocoametalview is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x1427289d0) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d408). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLOpenGLContext is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728a20) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d458). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_ShapeData is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728a98) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d4d0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_CocoaClosure is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728ae8) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d520). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_VideoData is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728b38) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d570). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_WindowData is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728b88) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d5c0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLWindow is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728bb0) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d5e8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class Cocoa_WindowListener is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728bd8) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d610). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDLView is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728c50) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d688). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class METAL_RenderData is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728cc8) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d700). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class METAL_TextureData is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728d18) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d750). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_RumbleMotor is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728d40) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d778). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[17817]: Class SDL_RumbleContext is implemented in both /opt/miniconda3/envs/highway/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x142728d90) and /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x15014d7c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# /opt/miniconda3/envs/highway/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
# Environment auto-registers when SimulatedEnv is imported from src
# (registration happens in src/simulated_env.py)

# %%
# Define scenario parameters (customize as needed)
setup = ScenarioParams(
    # Observation disturbances
    initial_position_x=GaussianMixtureParam(
        p=[1.0], 
        mu=[0.0, 0.0], 
        sigma=[0.005, 0.005]
    ),
    initial_position_y=GaussianMixtureParam(
        p=[1.0], 
        mu=[0.0, 0.0], 
        sigma=[0.005, 0.005]
    ),
    velocity_x=GaussianMixtureParam(
        p=[1.0],
        mu=[0.0, 0.0],
        sigma=[SQRT_2 * 0.005 / 0.1, SQRT_2 * 0.005 / 0.1]
    ),
    velocity_y=GaussianMixtureParam(
        p=[1.0],
        mu=[0.0, 0.0],
        sigma=[SQRT_2 * 0.005 / 0.1, SQRT_2 * 0.005 / 0.1]
    ),
    # Action disturbances
    high_lvl_ctrl_noise=ProbabilityParam(p=[0.0]),
    initial_speed=NormalParam(mu=8.0, sigma=0.5),
    initial_heading=ProbabilityParam(p=[0.33, 0.33, 0.33]),
    # Environment disturbances
    politeness=BetaParam(ab=[1, 1]),  # uniform distribution
    other_vehicle_speed=NormalParam(mu=16.0, sigma=2.0),
    entering_vehicle_position=GaussianMixtureParam(
        p=[1.0],
        mu=[5.0, 5.0],  # tip: mu=100.0 can cause more crashes
        sigma=[2.0, 2.0]
    )
)

# %%
TRAIN = False
RECORD_VIDEO = False  # Set True to save videos to roundabout_dqn/videos/

# Create the environment (render_mode only needed for video recording)
render_mode = "rgb_array" if RECORD_VIDEO else None
env = gym.make("SimulatedEnv-v0", render_mode=render_mode, scenario_params=setup)
obs, info = env.reset()

# Wrap with RecordVideo if recording
if RECORD_VIDEO:
    env = RecordVideo(
        env, video_folder="roundabout_dqn/videos/", episode_trigger=lambda e: True
    )
    env.unwrapped.set_record_video_wrapper(env)

# Create the model
model = DQN(
    "MlpPolicy",
    env,
    policy_kwargs=dict(net_arch=[256, 256]),
    learning_rate=5e-4,
    buffer_size=15000,
    learning_starts=200,
    batch_size=32,
    gamma=0.8,
    train_freq=1,
    gradient_steps=1,
    target_update_interval=50,
    verbose=1,
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train the model (if needed)
if TRAIN:
    model.learn(total_timesteps=int(2e4))
    model.save("roundabout_dqn/model")
    del model

# %%
# Load trained model
model = DQN.load("roundabout_dqn/best_model/best_model.zip", env=env, device="cpu")

# Configure environment
env.unwrapped.config["simulation_frequency"] = 15
env.unwrapped.config.update({
    "observation": {
        "type": "Kinematics",
        "absolute": True,
        "features_range": {
            "x": [-100, 100],
            "y": [-100, 100],
            "vx": [-15, 15],
            "vy": [-15, 15],
        },
        "vehicles_count": 5,
    },
})
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Robustness weights
robustness_weights = weights_from_vector([0.2042, 0.1982, 0.4393, 0.0111, 0.1471])

# %%
# Create fuzzer for rollouts
fuzzer = ScenarioFuzzer(env, model, robustness_weights=robustness_weights)
# fuzzer._apply_params(params)

# Run rollouts and collect metrics
N_ROLLOUTS = 500  # to record video
COMPUTE_LOG_PROB = True  
RETURN_SENSITIVITIY = False

logs = []
for i in range(N_ROLLOUTS):
    result = fuzzer.rollout(compute_log_prob=COMPUTE_LOG_PROB, return_sensitivity = RETURN_SENSITIVITIY)
    logs.append(result)
    if (i + 1) % 10 == 0:
        print(f"Completed {i + 1}/{N_ROLLOUTS} rollouts")

print(f"\nCollected {len(logs)} rollouts")
# Out:
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 10/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 20/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 30/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 40/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 50/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 60/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 70/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 80/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 90/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 100/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 110/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 120/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 130/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 140/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 150/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 160/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# ...
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 450/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 460/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 470/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 480/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 490/500 rollouts
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# /Users/dkoffical/Documents/GitHub/StanfordRoundabout/src/fuzzer.py:469: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   log_prob += (alpha - 1) * np.log(pol) + (beta_param  - 1) * np.log(1 - pol)
# Completed 500/500 rollouts
#
# Collected 500 rollouts

# %%
# # Store logs. Please don't run this unless you really have to. 

# import json
# # Keep index and item together
# failures_with_id = [(i+1, item) for i, item in enumerate(logs) if item['is_failure']]
# sorted_failures_with_id = sorted(failures_with_id, key=lambda x: x[1]['nominal_log_prob'], reverse=True)

# # Prepare sorted_failures_with_id for JSON
# json_failures = [{"id": idx, "item": item} for idx, item in sorted_failures_with_id]

# # Save both logs and failures to JSON
# with open("roundabout_dqn/falsification_results/eval_logs/logs_and_failures.json", "w") as f:
#     json.dump({
#         "logs": logs,
#         "sorted_failures_with_id": json_failures
#     }, f, indent=2)  # indent=2 makes it readable

# # --- Later, to load them ---
# with open("roundabout_dqn/falsification_results/eval_logs/logs_and_failures.json", "r") as f:
#     data = json.load(f)
#     logs_loaded = data["logs"]
#     sorted_failures_loaded = data["sorted_failures_with_id"]

# # Example check
# print(len(logs_loaded), len(sorted_failures_loaded))
# print(sorted_failures_loaded[0]["id"], sorted_failures_loaded[0]["item"]["nominal_log_prob"])

# %%
import os
import shutil

# Move top 10 most likely videos

if RECORD_VIDEO:
    # Paths
    src_dir = "./roundabout_dqn/videos"
    dst_dir = "./roundabout_dqn/videos/most_likely"
    os.makedirs(dst_dir, exist_ok=True)

    # Take top 10 failures (highest nominal_log_prob first)
    top_failures = sorted_failures_loaded[:10]

    for rank, failure in enumerate(top_failures, start=1):
        # Assuming 'item' contains the filename, or we construct it from 'id' or other info
        # If your video files are named like rl-video-episode-3.mp4, we need to know episode number
        original_filename = f"rl-video-episode-{failure['item']['metrics'].get('episode', failure['id'])}.mp4"
        
        src_path = os.path.join(src_dir, original_filename)
        
        # New filename with rank
        new_filename = f"{rank}-{original_filename}"
        dst_path = os.path.join(dst_dir, new_filename)
        
        # Move & rename
        if os.path.exists(src_path):
            shutil.move(src_path, dst_path)
            print(f"Moved: {src_path} → {dst_path}")
        else:
            print(f"File not found: {src_path}")
# Out:
# Moved: ./roundabout_dqn/videos/rl-video-episode-358.mp4 → ./roundabout_dqn/videos/other_fail/11-rl-video-episode-358.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-446.mp4 → ./roundabout_dqn/videos/other_fail/12-rl-video-episode-446.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-48.mp4 → ./roundabout_dqn/videos/other_fail/13-rl-video-episode-48.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-444.mp4 → ./roundabout_dqn/videos/other_fail/14-rl-video-episode-444.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-154.mp4 → ./roundabout_dqn/videos/other_fail/15-rl-video-episode-154.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-316.mp4 → ./roundabout_dqn/videos/other_fail/16-rl-video-episode-316.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-44.mp4 → ./roundabout_dqn/videos/other_fail/17-rl-video-episode-44.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-377.mp4 → ./roundabout_dqn/videos/other_fail/18-rl-video-episode-377.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-17.mp4 → ./roundabout_dqn/videos/other_fail/19-rl-video-episode-17.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-197.mp4 → ./roundabout_dqn/videos/other_fail/20-rl-video-episode-197.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-416.mp4 → ./roundabout_dqn/videos/other_fail/21-rl-video-episode-416.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-145.mp4 → ./roundabout_dqn/videos/other_fail/22-rl-video-episode-145.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-151.mp4 → ./roundabout_dqn/videos/other_fail/23-rl-video-episode-151.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-276.mp4 → ./roundabout_dqn/videos/other_fail/24-rl-video-episode-276.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-56.mp4 → ./roundabout_dqn/videos/other_fail/25-rl-video-episode-56.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-45.mp4 → ./roundabout_dqn/videos/other_fail/26-rl-video-episode-45.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-373.mp4 → ./roundabout_dqn/videos/other_fail/27-rl-video-episode-373.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-383.mp4 → ./roundabout_dqn/videos/other_fail/28-rl-video-episode-383.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-291.mp4 → ./roundabout_dqn/videos/other_fail/29-rl-video-episode-291.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-28.mp4 → ./roundabout_dqn/videos/other_fail/30-rl-video-episode-28.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode
mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-297.mp4 → ./roundabout_dqn/videos/other_fail/70-rl-video-episode-297.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-315.mp4 → ./roundabout_dqn/videos/other_fail/71-rl-video-episode-315.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-279.mp4 → ./roundabout_dqn/videos/other_fail/72-rl-video-episode-279.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-283.mp4 → ./roundabout_dqn/videos/other_fail/73-rl-video-episode-283.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-207.mp4 → ./roundabout_dqn/videos/other_fail/74-rl-video-episode-207.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-148.mp4 → ./roundabout_dqn/videos/other_fail/75-rl-video-episode-148.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-320.mp4 → ./roundabout_dqn/videos/other_fail/76-rl-video-episode-320.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-457.mp4 → ./roundabout_dqn/videos/other_fail/77-rl-video-episode-457.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-255.mp4 → ./roundabout_dqn/videos/other_fail/78-rl-video-episode-255.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-139.mp4 → ./roundabout_dqn/videos/other_fail/79-rl-video-episode-139.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-381.mp4 → ./roundabout_dqn/videos/other_fail/80-rl-video-episode-381.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-222.mp4 → ./roundabout_dqn/videos/other_fail/81-rl-video-episode-222.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-51.mp4 → ./roundabout_dqn/videos/other_fail/82-rl-video-episode-51.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-64.mp4 → ./roundabout_dqn/videos/other_fail/83-rl-video-episode-64.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-76.mp4 → ./roundabout_dqn/videos/other_fail/84-rl-video-episode-76.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-232.mp4 → ./roundabout_dqn/videos/other_fail/85-rl-video-episode-232.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-98.mp4 → ./roundabout_dqn/videos/other_fail/86-rl-video-episode-98.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-395.mp4 → ./roundabout_dqn/videos/other_fail/87-rl-video-episode-395.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-472.mp4 → ./roundabout_dqn/videos/other_fail/88-rl-video-episode-472.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-184.mp4 → ./roundabout_dqn/videos/other_fail/89-rl-video-episode-184.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-72.mp4 → ./roundabout_dqn/videos/other_fail/90-rl-video-episode-72.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-20.mp4 → ./roundabout_dqn/videos/other_fail/91-rl-video-episode-20.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-7.mp4 → ./roundabout_dqn/videos/other_fail/92-rl-video-episode-7.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-95.mp4 → ./roundabout_dqn/videos/other_fail/93-rl-video-episode-95.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-407.mp4 → ./roundabout_dqn/videos/other_fail/94-rl-video-episode-407.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-470.mp4 → ./roundabout_dqn/videos/other_fail/95-rl-video-episode-470.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-495.mp4 → ./roundabout_dqn/videos/other_fail/96-rl-video-episode-495.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-156.mp4 → ./roundabout_dqn/videos/other_fail/97-rl-video-episode-156.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-361.mp4 → ./roundabout_dqn/videos/other_fail/98-rl-video-episode-361.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-355.mp4 → ./roundabout_dqn/videos/other_fail/99-rl-video-episode-355.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-349.mp4 → ./roundabout_dqn/videos/other_fail/100-rl-video-episode-349.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-486.mp4 → ./roundabout_dqn/videos/other_fail/101-rl-video-episode-486.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-440.mp4 → ./roundabout_dqn/videos/other_fail/102-rl-video-episode-440.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-424.mp4 → ./roundabout_dqn/videos/other_fail/103-rl-video-episode-424.mp4
# Moved: ./roundabout_dqn/videos/rl-video-episode-144.mp4 → ./roundabout_dqn/videos/other_fail/104-rl-video-episode-144.mp4

# %% [markdown]
# ## Plot Log Probability vs Robustness Factors

# %%
import matplotlib.pyplot as plt

# Extract data from logs
log_probs = [r["nominal_log_prob"] for r in logs]
failures = [r["is_failure"] for r in logs]

# Separate by outcome
success_logs = [r for r in logs if not r["is_failure"]]
failure_logs = [r for r in logs if r["is_failure"]]

# --- Plot 1: Log Probability vs Each Metric ---
metric_names = ["min_distance", "avg_speed_ratio", "jerk_score", "brake_severity", "lane_changes", "on_road_frac"]
metric_labels = ["Min Distance (m)", "Avg Speed Ratio", "Jerk Score", "Brake Severity", "Lane Changes", "On-Road Fraction"]

fig1, axes1 = plt.subplots(2, 3, figsize=(14, 8))
axes1 = axes1.flatten()

for idx, (metric, label) in enumerate(zip(metric_names, metric_labels)):
    ax = axes1[idx]
    
    # Get metric values and log probs for each outcome
    success_vals = [r["metrics"][metric] for r in success_logs]
    success_lps = [r["log_prob"] for r in success_logs]
    failure_vals = [r["metrics"][metric] for r in failure_logs]
    failure_lps = [r["nominal_log_prob"] for r in failure_logs]
    
    # Scatter plot: metric value vs log probability
    if success_vals:
        ax.scatter(success_vals, success_lps, alpha=0.6, label="Success", color="blue", edgecolor="black", s=30)
    if failure_vals:
        ax.scatter(failure_vals, failure_lps, alpha=0.6, label="Failure", color="red", edgecolor="black", s=30)
    
    ax.set_xlabel(label)
    ax.set_ylabel("Log Probability")
    ax.set_title(f"Log Prob vs {label}")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.suptitle("Log Probability vs Robustness Metrics", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# --- Plot 2: Metric Distributions ---
fig2, axes2 = plt.subplots(2, 3, figsize=(14, 8))
axes2 = axes2.flatten()

for idx, (metric, label) in enumerate(zip(metric_names, metric_labels)):
    ax = axes2[idx]
    
    success_vals = [r["metrics"][metric] for r in success_logs]
    failure_vals = [r["metrics"][metric] for r in failure_logs]
    
    if success_vals:
        ax.hist(success_vals, bins=15, alpha=0.6, label="Success", color="blue", edgecolor="black")
    if failure_vals:
        ax.hist(failure_vals, bins=15, alpha=0.6, label="Failure", color="red", edgecolor="black")
    
    ax.set_xlabel(label)
    ax.set_ylabel("Count")
    ax.set_title(f"Distribution of {label}")
    ax.grid(True, alpha=0.3)
    ax.legend()

plt.suptitle("Metric Distributions by Outcome", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# Print summary statistics
n_failures = len(failure_logs)
print(f"\nSummary: {n_failures}/{len(logs)} failures ({100*n_failures/len(logs):.1f}%)")
print(f"Log prob range: [{min(log_probs):.1f}, {max(log_probs):.1f}]")
# Out:
# Summary: 59/500 failures (11.8%)
# Log prob range: [-946.9, -282.2]

# %% [markdown]
# ## Fuzzing for Critical Failures
#
# Use `ScenarioFuzzer` to find scenario parameters that minimize robustness while keeping scenarios plausible.

# %%
fuzzer = ScenarioFuzzer(env, model, robustness_weights=robustness_weights)

# %%
# Update fuzzer config for optimization
fuzzer.config = FuzzerConfig(
    n_samples=5, #3,           # rollouts per evaluation
    log_prob_weight=0.001,  # penalty for implausible scenarios
    verbose=True,
)

# Show parameter bounds
print("Parameter bounds:")
for name, (lo, hi), val in zip(PARAM_NAMES, fuzzer.config.bounds, fuzzer.config.initial_guess):
    print(f"  {name}: [{lo}, {hi}], initial={val}")
# Out:
# Parameter bounds:
#   entering_vehicle_mu: [0, 150], initial=5.0
#   other_vehicle_speed: [10, 25], initial=16.0
#   ctrl_noise_p: [0.0, 0.5], initial=0.0
#   initial_speed_mu: [0.0, 16.0], initial=8.0
#   politeness_alpha: [0.1, 10.0], initial=1.0
#   politeness_beta: [0.1, 10.0], initial=1.0
#   pos_x_sigma: [0.001, 0.1], initial=0.005
#   pos_y_sigma: [0.001, 0.1], initial=0.005
#   vel_x_sigma: [0.001, 0.1], initial=0.005
#   vel_y_sigma: [0.001, 0.1], initial=0.005

# %%
# Run optimization (WARNING: this can take a while)
# Uncomment to run
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

result = fuzzer.optimize(method="L-BFGS-B", maxiter=50)
print(f"\nOptimization finished: {result.message}")
print(f"Critical failure parameters:")
for name, val in fuzzer.get_params_dict(result.x).items():
    print(f"  {name}: {val:.4f}")
print(f"\nBest result: {fuzzer.best_result}")
# Out:
# [1] Rob: 0.5965 | LogProb: -580.05 | Obj: 1.1765
# [2] Rob: 0.8286 | LogProb: -669.20 | Obj: 1.4978
# [3] Rob: 0.7898 | LogProb: -642.95 | Obj: 1.4328
# [4] Rob: 0.7897 | LogProb: -601.43 | Obj: 1.3912
# [5] Rob: 0.6416 | LogProb: -673.40 | Obj: 1.3150
# [6] Rob: 0.8209 | LogProb: -636.12 | Obj: 1.4570
# [7] Rob: 0.8266 | LogProb: -585.52 | Obj: 1.4121
# [8] Rob: 0.6339 | LogProb: -618.30 | Obj: 1.2522
# [9] Rob: 0.8250 | LogProb: -670.05 | Obj: 1.4951
# [10] Rob: 0.8581 | LogProb: -612.25 | Obj: 1.4704
# [11] Rob: 0.5087 | LogProb: -541.68 | Obj: 1.0504
# [12] Rob: 0.3149 | LogProb: -729.08 | Obj: 1.0440
# [13] Rob: 0.4978 | LogProb: -883.36 | Obj: 1.3811
# [14] Rob: 0.4474 | LogProb: -734.37 | Obj: 1.1817
# [15] Rob: 0.4715 | LogProb: -652.71 | Obj: 1.1242
# [16] Rob: 0.4237 | LogProb: -884.58 | Obj: 1.3082
# [17] Rob: 0.6288 | LogProb: -908.51 | Obj: 1.5373
# [18] Rob: 0.1494 | LogProb: -641.96 | Obj: 0.7913
# [19] Rob: 0.2515 | LogProb: -652.43 | Obj: 0.9039
# [20] Rob: 0.1433 | LogProb: -685.41 | Obj: 0.8287
# [21] Rob: 0.4303 | LogProb: -712.70 | Obj: 1.1430
# [22] Rob: 0.3670 | LogProb: -688.98 | Obj: 1.0560
# [23] Rob: 0.4808 | LogProb: -676.70 | Obj: 1.1575
# [24] Rob: 0.4990 | LogProb: -578.72 | Obj: 1.0777
# [25] Rob: 0.7877 | LogProb: -639.11 | Obj: 1.4268
# [26] Rob: 0.6527 | LogProb: -684.30 | Obj: 1.3370
# [27] Rob: 0.6861 | LogProb: -704.35 | Obj: 1.3904
# [28] Rob: 0.8175 | LogProb: -656.81 | Obj: 1.4743
# [29] Rob: 0.5829 | LogProb: -579.99 | Obj: 1.1629
# [30] Rob: 0.7746 | LogProb: -689.57 | Obj: 1.4642
# [31] Rob: 0.8248 | LogProb: -708.33 | Obj: 1.5332
# [32] Rob: 0.4666 | LogProb: -631.09 | Obj: 1.0977
# [207] Rob: 0.6879 | LogProb: -571.04 | Obj: 1.2590
# [208] Rob: 0.8257 | LogProb: -587.04 | Obj: 1.4128
# [209] Rob: 0.6588 | LogProb: -581.80 | Obj: 1.2406
# [210] Rob: 0.6346 | LogProb: -659.54 | Obj: 1.2941
# [211] Rob: 0.8391 | LogProb: -607.95 | Obj: 1.4471
# [212] Rob: 0.7260 | LogProb: -582.75 | Obj: 1.3088
# [213] Rob: 0.7559 | LogProb: -652.27 | Obj: 1.4082
# [214] Rob: 0.6317 | LogProb: -609.04 | Obj: 1.2407
# [215] Rob: 0.6270 | LogProb: -631.88 | Obj: 1.2589
# [216] Rob: 0.7326 | LogProb: -624.80 | Obj: 1.3574
# [217] Rob: 0.8601 | LogProb: -602.55 | Obj: 1.4626
# [218] Rob: 0.8785 | LogProb: -578.43 | Obj: 1.4570
# [219] Rob: 0.8708 | LogProb: -563.64 | Obj: 1.4344
# [220] Rob: 0.6882 | LogProb: -561.55 | Obj: 1.2497
# [221] Rob: 0.8761 | LogProb: -566.36 | Obj: 1.4425
# [222] Rob: 0.7082 | LogProb: -610.38 | Obj: 1.3186
# [223] Rob: 0.8360 | LogProb: -652.53 | Obj: 1.4885
# [224] Rob: 0.4737 | LogProb: -540.05 | Obj: 1.0137
# [225] Rob: 0.7600 | LogProb: -647.83 | Obj: 1.4078
# [226] Rob: 0.7875 | LogProb: -666.57 | Obj: 1.4541
# [227] Rob: 0.8529 | LogProb: -641.81 | Obj: 1.4947
# [228] Rob: 0.8543 | LogProb: -761.11 | Obj: 1.6154
# [229] Rob: 0.6847 | LogProb: -566.79 | Obj: 1.2515
# [230] Rob: 0.8332 | LogProb: -618.52 | Obj: 1.4517
# [231] Rob: 0.8395 | LogProb: -693.48 | Obj: 1.5330
#
# Optimization finished: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Critical failure parameters:
#   entering_vehicle_mu: 5.0000
#   other_vehicle_speed: 16.0000
#   ctrl_noise_p: 0.0000
#   initial_speed_mu: 8.0000
#   politeness_alpha: 1.0000
#   politeness_beta: 1.0000
#   pos_x_sigma: 0.0050
#   pos_y_sigma: 0.0050
#   vel_x_sigma: 0.0050
#   vel_y_sigma: 0.0050
#
# Best result: {'eval': 18, 'params': array([0.0000000e+00, 1.0000000e+01, 0.0000000e+00, 0.0000000e+00,
#        1.0000000e-01, 1.0000001e-01, 1.0000000e-03, 1.0000000e-03,
#        1.0000000e-03, 1.0000000e-01]), 'robustness': np.float64(0.14937564527466993), 'failures': [{'log_prob': -1037.5010986328125, 'nominal_log_prob': -618.7974853515625, 'is_failure': True, 'robustness': 0.0, 'metrics': {'success': 0.0, 'min_distance': 5.054745442178528, 'avg_speed_ratio': 0.8641174933186485, 'jerk_score': 13.338305286036737, 'brake_severity': 5.365420501856397, 'lane_changes': 0, 'on_road_frac': 1.0, 'cumulative_reward': 7.083333333333334}}, {'log_prob': -391.39715576171875, 'nominal_log_prob': -362.5419006347656, 'is_failure': True, 'robustness': 0.0, 'metrics': {'success': 0.0, 'min_distance': 5.185724015785993, 'avg_speed_ratio': 0.7636249803602158, 'jerk_score': 32.95780513999216, 'brake_severity': 4.422539769338813, 'lane_changes': 0, 'on_road_frac': 1.0, 'cumulative_reward': 3.0833333333333335}}, {'log_prob': -278.3093566894531, 'nominal_log_prob': -537.2838745117188, 'is_failure': True, 'robustness': 0.0, 'metrics': {'success': 0.0, 'min_distance': 2.8959659596288345, 'avg_speed_ratio': 0.7631742763305713, 'jerk_score': 33.07761215232972, 'brake_severity': 4.421196245952813, 'lane_changes': 0, 'on_road_frac': 1.0, 'cumulative_reward': 3.0833333333333335}}], 'nominal_log_prob': np.float64(-641.9562316894531), 'objective': np.float64(0.7913318769641231)}

# %%
fuzzer.best_result
# Out:
# {'eval': 27,
#  'params': array([4.95776270e+01, 1.87668872e+01, 1.53715955e-01, 5.54054473e+00,
#         7.23311281e-01, 3.76688719e+00, 3.77027236e-03, 3.42060315e-02,
#         3.42060315e-02, 3.42060315e-02]),
#  'robustness': np.float64(0.14393705207791135),
#  'nominal_log_prob': np.float64(-474.61235961914065),
#  'objective': np.float64(0.618549411697052)}

# %%
all_failures = [f for rec in fuzzer._history for f in rec["failures"]]
print(f"Total failures found: {len(all_failures)}")
# Out:
# Total failures found: 152

# %%
# Store logs. Please don't run this unless you really have to. 

import json
# Keep index and item together
failures_with_id = [(i+1, item) for i, item in enumerate(all_failures) ]
sorted_failures_with_id = sorted(failures_with_id, key=lambda x: x[1]['nominal_log_prob'], reverse=True)

# %%
# Prepare sorted_failures_with_id for JSON
json_failures = [{"id": idx, "item": item} for idx, item in sorted_failures_with_id]

# Save both logs and failures to JSON
with open("roundabout_dqn/falsification_results/eval_logs/optim_failures.json", "w") as f:
    json.dump({
        "sorted_failures_with_id": json_failures
    }, f, indent=2)  # indent=2 makes it readable

# # --- Later, to load them ---
# with open("roundabout_dqn/falsification_results/eval_logs/logs_and_failures.json", "r") as f:
#     data = json.load(f)
#     logs_loaded = data["logs"]
#     sorted_failures_loaded = data["sorted_failures_with_id"]

# # Example check
# print(len(logs_loaded), len(sorted_failures_loaded))
# print(sorted_failures_loaded[0]["id"], sorted_failures_loaded[0]["item"]["nominal_log_prob"])

# %% [markdown]
# Final Failure Analysis

# %%
# --- Later, to load them ---
with open("roundabout_dqn/falsification_results/eval_logs/logs_and_failures.json", "r") as f:
    data = json.load(f)
    logs_loaded = data["logs"]
    sorted_failures_loaded = data["sorted_failures_with_id"]
    
with open("roundabout_dqn/falsification_results/eval_logs/optim_failures.json", "r") as f:
    data = json.load(f)
    # logs_loaded = data["logs"]
    sorted_failures_loaded += data["sorted_failures_with_id"]

# Example check
print(len(sorted_failures_loaded))
# Out:
# 256

# %%
failure_log_probs = np.array([d['item']['nominal_log_prob'] for d in sorted_failures_loaded])

# %%
failure_log_probs = np.sort(failure_log_probs)[::-1]

# %% [markdown]
# Compare to nominal distribution

# %%
# Create fuzzer for rollouts
fuzzer = ScenarioFuzzer(env, model, robustness_weights=robustness_weights)
# fuzzer._apply_params(params)

# Run rollouts and collect metrics
N_ROLLOUTS = 231*5 + 500  # to record video
COMPUTE_LOG_PROB = True  
RETURN_SENSITIVITIY = False

logs = []
# Completed 950/1655 rollouts
# Completed 960/1655 rollouts
# Completed 970/1655 rollouts
# Completed 980/1655 rollouts
# Completed 990/1655 rollouts
# Completed 1000/1655 rollouts
# Completed 1010/1655 rollouts
# Completed 1020/1655 rollouts
# Completed 1030/1655 rollouts
# Completed 1040/1655 rollouts
# Completed 1050/1655 rollouts
# Completed 1060/1655 rollouts
# Completed 1070/1655 rollouts
# Completed 1080/1655 rollouts
# Completed 1090/1655 rollouts
# Completed 1100/1655 rollouts
# Completed 1110/1655 rollouts
# Completed 1120/1655 rollouts
# Completed 1130/1655 rollouts
# Completed 1140/1655 rollouts
# Completed 1150/1655 rollouts
# Completed 1160/1655 rollouts
# Completed 1170/1655 rollouts
# Completed 1180/1655 rollouts
# Completed 1190/1655 rollouts
# Completed 1200/1655 rollouts
# Completed 1210/1655 rollouts
# Completed 1220/1655 rollouts
# Completed 1230/1655 rollouts
# Completed 1240/1655 rollouts
# Completed 1250/1655 rollouts
# Completed 1260/1655 rollouts
# Completed 1270/1655 rollouts
# Completed 1280/1655 rollouts
# Completed 1290/1655 rollouts
# Completed 1300/1655 rollouts
# Completed 1310/1655 rollouts
# Completed 1320/1655 rollouts
# Completed 1330/1655 rollouts
# Completed 1340/1655 rollouts
# Completed 1350/1655 rollouts
# Completed 1360/1655 rollouts
# Completed 1370/1655 rollouts
# Completed 1380/1655 rollouts
# Completed 1390/1655 rollouts
# Completed 1400/1655 rollouts
# Completed 1410/1655 rollouts
# Completed 1420/1655 rollouts
# Completed 1430/1655 rollouts
# Completed 1440/1655 rollouts
# Completed 1450/1655 rollouts
# Completed 1460/1655 rollouts
# Completed 1470/1655 rollouts
# Completed 1480/1655 rollouts
# Completed 1490/1655 rollouts
# Completed 1500/1655 rollouts
# Completed 1510/1655 rollouts
# Completed 1520/1655 rollouts
# Completed 1530/1655 rollouts
# Completed 1540/1655 rollouts
# Completed 1550/1655 rollouts
# Completed 1560/1655 rollouts
# Completed 1570/1655 rollouts
# Completed 1580/1655 rollouts
# Completed 1590/1655 rollouts
# Completed 1600/1655 rollouts
# Completed 1610/1655 rollouts
# Completed 1620/1655 rollouts
# Completed 1630/1655 rollouts
# Completed 1640/1655 rollouts
# Completed 1650/1655 rollouts
#
# Collected 1655 rollouts

# %%
# Save baseline logs 

import json
# Keep index and item together
failures_with_id = [(i+1, item) for i, item in enumerate(logs) if item['is_failure']]
sorted_failures_with_id = sorted(failures_with_id, key=lambda x: x[1]['nominal_log_prob'], reverse=True)

# Prepare sorted_failures_with_id for JSON
json_failures = [{"id": idx, "item": item} for idx, item in sorted_failures_with_id]

# Save both logs and failures to JSON
with open("roundabout_dqn/falsification_results/eval_logs/baseline.json", "w") as f:
    json.dump({
        "logs": logs,
        "sorted_failures_with_id": json_failures
    }, f, indent=2)  # indent=2 makes it readable

# %%
# --- Later, to load them ---
with open("roundabout_dqn/falsification_results/eval_logs/baseline.json", "r") as f:
    data = json.load(f)
    logs_loaded = data["logs"]
    sorted_failures_loaded = data["sorted_failures_with_id"]

# Example check
print(len(logs_loaded), len(sorted_failures_loaded))
print(sorted_failures_loaded[0]["id"], sorted_failures_loaded[0]["item"]["nominal_log_prob"])

nominal_log_probs = np.array([d['item']['nominal_log_prob'] for d in sorted_failures_loaded])
# Out:
# 1655 191
# 866 -335.90911865234375

# %%
nominal_log_probs = np.sort(nominal_log_probs)[::-1]

# %%
env.close()

# %%
failure_log_probs
# Out:
# array([-296.3253479 , -296.78076172, -304.43725586, -325.78588867,
#        -328.26382446, -328.49157715, -329.02590942, -332.8253479 ,
#        -334.2355957 , -335.90911865, -337.03738403, -341.2784729 ,
#        -342.88983154, -344.08444214, -345.90847778, -347.87631226,
#        -350.03741455, -351.20001221, -352.88345337, -353.50186157,
#        -357.62716675, -361.11407471, -361.33740234, -361.57922363,
#        -362.47796631, -362.54190063, -364.38735962, -366.45559692,
#        -366.99417114, -375.60784912, -383.17205811, -385.78479004,
#        -390.21356201, -390.86157227, -394.80584717, -395.77972412,
#        -400.10470581, -400.66766357, -404.03695679, -409.49517822,
#        -410.83273315, -411.5586853 , -415.57647705, -415.91516113,
#        -416.0690918 , -416.18786621, -419.85629272, -424.77764893,
#        -427.13674927, -427.89028931, -428.08383179, -430.96447754,
#        -436.27453613, -438.49298096, -440.24353027, -440.30517578,
#        -441.78393555, -442.56344604, -443.36251831, -447.55224609,
#        -448.03808594, -449.49145508, -454.16864014, -455.28445435,
#        -456.28482056, -458.14785767, -458.55603027, -459.54431152,
#        -461.86346436, -463.48510742, -465.02978516, -465.25588989,
#        -465.54443359, -466.80310059, -467.53616333, -467.69897461,
#        -467.78033447, -468.03292847, -468.91134644, -471.15270996,
#        -471.9354248 , -472.12835693, -473.02365112, -477.30401611,
#        -478.38427734, -478.54507446, -479.25387573, -482.03759766,
#        -483.36785889, -483.97943115, -484.203125  , -484.45602417,
#        -485.03659058, -487.36785889, -487.76904297, -488.25933838,
#        -488.72988892, -493.86169434, -495.39459229, -497.41021729,
#        -499.41503906, -504.05505371, -505.25158691, -505.75915527,
#        -508.82116699, -512.1762085 , -514.12463379, -514.3805542 ,
#        -514.62719727, -514.72033691, -523.18707275, -525.59490967,
#        -525.81848145, -525.88873291, -527.34985352, -528.02416992,
#        -529.62255859, -534.44061279, -536.13623047, -537.28387451,
#        -542.12506104, -542.24481201, -542.8012085 , -543.69024658,
#        -543.94555664, -547.93133545, -551.8651123 , -552.53393555,
#        -552.67956543, -552.82849121, -553.9510498 , -556.87609863,
#        -556.91516113, -558.06970215, -559.08947754, -559.60760498,
#        -560.11676025, -561.22247314, -562.06304932, -562.09307861,
#        -562.52020264, -563.04638672, -565.50653076, -566.46264648,
#        -566.59777832, -567.24768066, -567.70251465, -569.13427734,
#        -570.25262451, -572.1105957 , -572.17687988, -573.90722656,
#        -575.69775391, -576.54528809, -577.35546875, -577.47113037,
#        -579.82116699, -580.03710938, -580.87524414, -581.54968262,
#        -581.87701416, -584.01306152, -584.81713867, -588.65435791,
#        -588.86889648, -589.45373535, -589.76904297, -591.13189697,
#        -591.57525635, -591.64770508, -592.42724609, -593.92163086,
#        -594.24139404, -594.65368652, -594.6875    , -594.97662354,
#        -597.15075684, -604.60900879, -605.12780762, -605.67364502,
#        -607.23095703, -607.34918213, -607.4352417 , -608.14929199,
#        -612.92602539, -613.76867676, -618.33300781, -618.79748535,
#        -620.54187012, -624.92706299, -625.03063965, -625.97729492,
#        -626.04040527, -627.0291748 , -636.56195068, -637.45904541,
#        -638.28491211, -638.95947266, -643.64685059, -648.50537109,
#        -651.05224609, -651.07073975, -651.56542969, -654.14337158,
#        -664.72839355, -666.390625  , -666.64208984, -679.66802979,
#        -682.00653076, -683.15966797, -684.88964844, -686.82940674,
#        -686.9074707 , -694.4329834 , -696.07098389, -699.61767578,
#        -699.95202637, -703.15136719, -703.97912598, -708.0682373 ,
#        -709.75537109, -709.95709229, -710.0111084 , -710.8046875 ,
#        -713.13323975, -713.85101318, -714.38781738, -718.6640625 ,
#        -718.68292236, -723.26739502, -726.47509766, -730.52484131,
#        -735.24810791, -736.54144287, -737.31848145, -738.80963135,
#        -740.27246094, -745.48822021, -753.28656006, -760.91571045,
#        -761.66204834, -771.23547363, -782.7878418 , -784.78979492,
#        -788.81054688, -797.91339111, -798.0078125 , -799.70996094,
#        -809.16571045, -809.85229492, -825.24163818, -829.92700195,
#        -891.56243896, -895.27636719, -917.13513184, -921.28167725])

# %%
from src.failure_probability import estimate_failure_probability, print_failure_probability_report
import numpy as np
from scipy.stats import beta as beta_dist
import matplotlib.pyplot as plt

# Estimate failure probability from the collected rollout logs
# Uniform prior Beta(1, 1) — no prior bias toward safe or unsafe
TARGET_DELTA = 0.4  # safety threshold: we want p_fail < this

result = estimate_failure_probability(logs, prior_alpha=1.0, prior_beta=1.0, target_delta=TARGET_DELTA)
print_failure_probability_report(result, target_delta=TARGET_DELTA)

# --- Plot posterior distribution over p_fail ---
fig, ax = plt.subplots(figsize=(8, 4))

p_vals = np.linspace(0, 1, 500)
posterior = beta_dist(result["posterior_alpha"], result["posterior_beta"])
ax.plot(p_vals, posterior.pdf(p_vals), color="steelblue", linewidth=2, label="Bayesian Estimation $p_{\\mathrm{fail}}$")

# Shade 95% credible interval
ci_mask = (p_vals >= result["ci_95_low"]) & (p_vals <= result["ci_95_high"])
ax.fill_between(p_vals[ci_mask], posterior.pdf(p_vals[ci_mask]), alpha=0.3, color="steelblue", label="95% CI")

# Mark point estimates
ax.axvline(result["mle"], color="red", linestyle="--", linewidth=1.5, label=f"Direct SamplingE = {result['mle']:.3f}")
ax.axvline(result["posterior_mean"], color="navy", linestyle="-", linewidth=1.5, label=f"Bayesian Estimation mean = {result['posterior_mean']:.3f}")
# ax.axvline(TARGET_DELTA, color="orange", linestyle=":", linewidth=1.5, label=f"Target δ = {TARGET_DELTA}")

ax.set_xlabel("$p_{\\mathrm{fail}}$")
ax.set_ylabel("Density")
ax.set_title(f"Bayesian Posterior over Failure Probability\n"
             f"(n={result['n_failures']} failures / m={result['n_rollouts']} rollouts, "
             f"uniform prior)")
ax.legend(loc="upper left")
ax.set_xlim(0, 1)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Failure Probability Estimation (59 failures in 500 rollouts)
#   MLE (point estimate):    0.1180
#   Bayesian posterior mean: 0.1195  ± 0.0145 (std)
#   95% credible interval:   [0.0926, 0.1493]
#   95% one-sided bound:     p_fail < 0.1441 with 95% confidence
#   P(p_fail < 0.4):          1.0000
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2010: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   p.space          = oneOf(self._space_widths)("space")
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2020: PyparsingDeprecationWarning: 'leaveWhitespace' deprecated - use 'leave_whitespace'
#   )("sym").leaveWhitespace()
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:1984: PyparsingDeprecationWarning: 'setName' deprecated - use 'set_name'
#   val.setName(key)
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:1987: PyparsingDeprecationWarning: 'setParseAction' deprecated - use 'set_parse_action'
#   val.setParseAction(getattr(self, key))
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2088: PyparsingDeprecationWarning: 'endQuoteChar' argument is deprecated, use 'end_quote_char'
#   p.text = cmd(r"\text", QuotedString('{', '\\', endQuoteChar="}"))
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2146: PyparsingDeprecationWarning: 'unquoteResults' argument is deprecated, use 'unquote_results'
#   p.math_string   = QuotedString('$', '\\', unquoteResults=False)
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2170: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   result = self._expression.parseString(s)
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/pyparsing/util.py:466: PyparsingDeprecationWarning: 'parseAll' argument is deprecated, use 'parse_all'
#   return fn(self, *args, **kwargs)
# /Users/dkoffical/envs/myenv312/lib/python3.12/site-packages/matplotlib/_mathtext.py:2178: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   ParserElement.resetCache()

# %%
## Importance Sampling Failure Probability Estimation
Only shift 1–2 parameters that directly drive failures.

# %%
from src.failure_probability import importance_sampling_estimate
import copy

# ── Define proposal distribution q(τ) ──
# IMPORTANT: Only shift parameters that drive failures.
# Keep observation noise (position/velocity sigma) IDENTICAL to nominal —
# these are evaluated per-timestep × per-car, so even tiny differences
# compound into massive log-weight gaps (Example 7.4 in the textbook).
proposal_params = copy.deepcopy(NOMINAL)

# Shift entering vehicle position — the notebook's own tip says mu=100
# causes more crashes. Use a moderate shift to keep overlap with nominal.
proposal_params.entering_vehicle_position = GaussianMixtureParam(
    p=[1.0], mu=[25.0, 25.0], sigma=[4.0, 4.0],
)
# Slightly faster other vehicles (nominal mu=16, sigma=2)
proposal_params.other_vehicle_speed = NormalParam(mu=18.0, sigma=2.5)

# ── Run rollouts under proposal ──
env_q = gym.make("SimulatedEnv-v0", render_mode=None, scenario_params=proposal_params)
env_q.reset()
fuzzer_q = ScenarioFuzzer(
    env_q, model,
    scenario_params=proposal_params,
    robustness_weights=robustness_weights,
    config=FuzzerConfig(verbose=False),
    seed=42,
)

N_IS = 500
is_logs = []
for i in range(N_IS):
    r = fuzzer_q.rollout(compute_log_prob=True)
    is_logs.append(r)
    if (i + 1) % 50 == 0:
        nf = sum(1 for x in is_logs if x["is_failure"])
        print(f"  {i+1}/{N_IS} rollouts  ({nf} failures so far)")
env_q.close()

# ── Compute IS estimate ──
is_result = importance_sampling_estimate(is_logs, self_normalized=False)
sn_result = importance_sampling_estimate(is_logs, self_normalized=True)

print(f"\n{'─'*55}")
print(f"Importance Sampling  (Eq 7.12, standard)")
print(f"  Proposal failure rate:   {is_result['n_proposal_failures']}/{N_IS}"
      f"  ({is_result['n_proposal_failures']/N_IS:.2%})")
print(f"  IS  p_fail estimate:     {is_result['p_fail_is']:.4f} ± {is_result['is_std']:.4f}")
print(f"  Effective sample size:   {is_result['ess']:.1f} / {N_IS}")
print()
print(f"Self-Normalized IS  (Eq 7.33, Algorithm 7.9)")
print(f"  SN-IS p_fail estimate:   {sn_result['p_fail_is']:.4f}")
print(f"  Effective sample size:   {sn_result['ess']:.1f} / {N_IS}")
print(f"{'─'*55}")
print(f"\nComparison:")
bayesian_mean = result["posterior_mean"] if isinstance(result, dict) and "posterior_mean" in result else "N/A"
print(f"  Direct (MLE from nominal):       {sum(1 for r in logs if r['is_failure'])/len(logs):.4f}")
print(f"  Bayesian posterior mean:         {bayesian_mean}")
print(f"  Importance sampling (standard):  {is_result['p_fail_is']:.4f}")
print(f"  Importance sampling (self-norm): {sn_result['p_fail_is']:.4f}")
# Out:
#   50/500 rollouts  (7 failures so far)
#   100/500 rollouts  (13 failures so far)
#   150/500 rollouts  (20 failures so far)
#   200/500 rollouts  (23 failures so far)
#   250/500 rollouts  (26 failures so far)
#   300/500 rollouts  (31 failures so far)
#   350/500 rollouts  (38 failures so far)
#   400/500 rollouts  (44 failures so far)
#   450/500 rollouts  (51 failures so far)
#   500/500 rollouts  (60 failures so far)
#
# ───────────────────────────────────────────────────────
# Importance Sampling  (Eq 7.12, standard)
#   Proposal failure rate:   60/500  (12.00%)
#   IS  p_fail estimate:     5972868.0071 ± 2489809.2326
#   Effective sample size:   5.7 / 500
#
# Self-Normalized IS  (Eq 7.33, Algorithm 7.9)
#   SN-IS p_fail estimate:   0.2510
#   Effective sample size:   5.7 / 500
# ───────────────────────────────────────────────────────
#
# Comparison:
#   Direct (MLE from nominal):       0.1180
#   Bayesian posterior mean:         0.165
#   Importance sampling (standard):  5972868.0071
#   Importance sampling (self-norm): 0.2510

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

# 1. Importance weight distribution
w = is_result["weights"]
log_w = np.log(w + 1e-300)
axes[0].hist(log_w, bins=40, color="steelblue", edgecolor="black", alpha=0.7)
axes[0].axvline(0, color="red", linestyle="--", label="w=1 (p=q)")
axes[0].set_xlabel("log importance weight  (log p/q)")
axes[0].set_ylabel("Count")
axes[0].set_title("Importance Weight Distribution")
axes[0].legend()

# 2. Weights vs failure indicator
fail_arr = np.array([1.0 if r["is_failure"] else 0.0 for r in is_logs])
axes[1].scatter(
    np.arange(len(w))[fail_arr == 0], w[fail_arr == 0],
    alpha=0.3, s=10, label="Success", color="blue",
)
axes[1].scatter(
    np.arange(len(w))[fail_arr == 1], w[fail_arr == 1],
    alpha=0.5, s=15, label="Failure", color="red",
)
axes[1].set_xlabel("Rollout index")
axes[1].set_ylabel("Importance weight w")
axes[1].set_title("Weights by Outcome")
axes[1].legend()

plt.tight_layout()
plt.show()
